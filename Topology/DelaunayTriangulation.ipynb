# %%
import numpy as np
from scipy.spatial import Delaunay
from matplotlib import pylab as plt
# %matplotlib inline

# %%
# circular ring
ring = np.array([np.random.normal(loc=1, scale=0.01)*np.array([np.cos(t), np.sin(t)]) for t in np.linspace(0, 2*np.pi, 101)])[1:]

# %%
plt.plot(ring[:,0], ring[:,1])

# %%
ring_tri = Delaunay(ring)

# %%
ring_tri.simplices.shape
# Out:
# (161, 3)

# %%
ring_tri.simplices
# Out:
# array([[94, 34, 66],
#        [34, 94, 11],
#        [69, 65, 63],
#        [19, 18, 20],
#        [70, 83, 66],
#        [70, 76, 83],
#        [83, 90, 66],
#        [90, 94, 66],
#        [95, 94, 93],
#        [60, 64, 66],
#        [64, 65, 66],
#        [65, 64, 63],
#        [64, 62, 63],
#        [65, 67, 66],
#        [67, 70, 66],
#        [43, 42, 44],
#        [35, 36, 34],
#        [12, 11, 13],
#        [12, 15, 11],
#        [16, 15, 13],
#        [77, 76, 75],
#        [78, 77, 75],
#        [82, 84, 83],
#        [86, 84, 82],
#        [84, 85, 83],
#        [85, 84, 86],
#        [28, 30, 29],
#        [94,  0, 11],
#        [11, 10, 13],
#        [10,  8, 13],
#        [ 0,  6, 11],
#        [ 6,  0,  3],
#        [94, 92, 93],
#        [97, 95, 93],
#        [62, 59, 57],
#        [58, 60, 66],
#        [59, 58, 57],
#        [58, 59, 60],
#        [58, 56, 57],
#        [46, 34, 40],
#        [43, 46, 40],
#        [58, 46, 53],
#        [34, 46, 66],
#        [46, 58, 66],
#        [68, 65, 69],
#        [68, 67, 65],
#        [70, 68, 69],
#        [67, 68, 70],
#        [41, 43, 40],
#        [41, 42, 43],
#        [42, 41, 38],
#        [35, 33, 32],
#        [33, 35, 34],
#        [39, 41, 40],
#        [41, 39, 38],
#        [34, 39, 40],
#        [36, 39, 34],
#        [22, 27, 34],
#        [27, 28, 29],
#        [21, 19, 20],
#        [21, 22, 19],
#        [15, 14, 13],
#        [14, 12, 13],
#        [12, 14, 15],
#        [16, 17, 15],
#        [22, 17, 19],
#        [19, 17, 18],
#        [17, 16, 18],
#        [15, 17, 11],
#        [17, 34, 11],
#        [17, 22, 34],
#        [71, 70, 69],
#        [72, 71, 69],
#        [79, 77, 78],
#        [76, 79, 83],
#        [77, 79, 76],
#        [87, 86, 88],
#        [87, 85, 86],
#        [85, 87, 83],
#        [ 6,  4,  5],
#        [ 4,  6,  3],
#        [ 1, 99, 98],
#        [ 0, 99,  1],
#        [ 8,  7,  5],
#        [ 7,  6,  5],
#        [10,  9,  8],
#        [ 9,  7,  8],
#        [ 7,  9,  6],
#        [ 9, 10, 11],
#        [ 6,  9, 11],
#        [90, 91, 94],
#        [91, 92, 94],
#        [92, 91, 93],
#        [91, 88, 93],
#        [97, 96, 95],
#        [95, 96, 94],
#        [96,  0, 94],
#        [96, 99,  0],
#        [96, 97, 98],
#        [99, 96, 98],
#        [59, 61, 60],
#        [61, 59, 62],
#        [61, 64, 60],
#        [61, 62, 64],
#        [54, 55, 56],
#        [58, 54, 56],
#        [54, 58, 53],
#        [54, 52, 55],
#        [52, 54, 53],
#        [47, 44, 48],
#        [49, 47, 48],
#        [47, 49, 46],
#        [39, 37, 38],
#        [37, 39, 36],
#        [37, 35, 38],
#        [37, 36, 35],
#        [31, 27, 29],
#        [27, 31, 34],
#        [30, 31, 29],
#        [31, 30, 32],
#        [33, 31, 32],
#        [31, 33, 34],
#        [23, 21, 20],
#        [21, 23, 22],
#        [73, 71, 72],
#        [70, 73, 76],
#        [71, 73, 70],
#        [80, 79, 78],
#        [89, 87, 88],
#        [91, 89, 88],
#        [89, 91, 90],
#        [89, 90, 83],
#        [87, 89, 83],
#        [ 2,  4,  3],
#        [ 4,  2,  1],
#        [ 0,  2,  3],
#        [ 2,  0,  1],
#        [51, 52, 53],
#        [46, 51, 53],
#        [49, 51, 46],
#        [47, 45, 44],
#        [45, 47, 46],
#        [45, 43, 44],
#        [45, 46, 43],
#        [23, 24, 22],
#        [74, 72, 75],
#        [74, 73, 72],
#        [76, 74, 75],
#        [73, 74, 76],
#        [79, 81, 83],
#        [80, 81, 79],
#        [81, 82, 83],
#        [81, 80, 82],
#        [51, 50, 52],
#        [50, 51, 49],
#        [50, 49, 48],
#        [26, 24, 25],
#        [27, 26, 28],
#        [26, 25, 28],
#        [26, 27, 22],
#        [24, 26, 22]], dtype=int32)

# %%
ring[3]
# Out:
# array([ 0.96415756,  0.24755359])

# %%
ring[7]
# Out:
# array([ 0.88066325,  0.48414872])

# %%
ring[2]
# Out:
# array([ 0.98236005,  0.1873952 ])

# %%
plt.triplot(ring[:,0], ring[:,1], ring_tri.simplices)
# Out:
# [<matplotlib.lines.Line2D at 0x10c8846d0>,
#  <matplotlib.lines.Line2D at 0x10c8848d0>]

# %%
from mogu.topology import AlphaComplex

# %%
ring_c = AlphaComplex(ring, 0.1)

# %%
print(ring_c.betti_number(0))
print(ring_c.betti_number(1))
print(ring_c.betti_number(2))
# Out:
# 1
# 1
# 0
