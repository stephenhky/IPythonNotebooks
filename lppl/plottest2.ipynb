# %%
import numpy as np
from matplotlib import pyplot as plt

from lppl.fit import LPPLModel

# %%
ts = np.linspace(0, 9, 91)

# %%
param = {
            'A': 1.0,
            'B': -0.4,
            'C': 0.025,
            'phi': 4.1,
            'omega': 7.877*10,
            'm': 0.445,
            'tc': 10.0
        }
lppl_model = LPPLModel.load_model_from_parameters(param)

# %%
prices = lppl_model(ts)

# %%
plt.plot(ts, prices)

# %%
fitted_lppl_model = LPPLModel()
fitted_lppl_model.fit(ts, prices)

# %%
plt.plot(ts, fitted_lppl_model(ts))

# %%
print(fitted_lppl_model)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /Users/stephenhky/PycharmProjects/IPythonNotebooks/lppl/plottest2.ipynb Cell 8 line 1
# ----> <a href='vscode-notebook-cell:/Users/stephenhky/PycharmProjects/IPythonNotebooks/lppl/plottest2.ipynb#X11sZmlsZQ%3D%3D?line=0'>1</a> print(fitted_lppl_model)
#
# File ~/opt/anaconda3/envs/quantumphy/lib/python3.10/site-packages/lppl/fit.py:131, in LPPLModel.__str__(self)
#     130 def __str__(self):
# --> 131     return self.summary()
#
# File ~/opt/anaconda3/envs/quantumphy/lib/python3.10/site-packages/lppl/fit.py:122, in LPPLModel.summary(self)
#     120 summarytxt += "m: {}".format(self.m) + '\n'
#     121 summarytxt += "omega: {}".format(self._omega) + '\n'
# --> 122 summarytxt += "A: {}".fromat(self._A) + '\n'
#     123 summarytxt += "B: {}".format(self._B) + '\n'
#     124 summarytxt += "C: {}".format(self._C) + '\n'
#
# AttributeError: 'str' object has no attribute 'fromat'
