# %%
import numpy as np
from matplotlib import pyplot as plt

from lppl.fit import LPPLModel

# %%
ts = np.linspace(0, 9, 91)

# %%
param = {
            'A': 1.0,
            'B': -0.4,
            'C': 0.025,
            'phi': 4.1,
            'omega': 7.877,
            'm': 0.445,
            'tc': 10.0
        }
lppl_model = LPPLModel.load_model_from_parameters(param)

# %%
prices = lppl_model(ts)

# %%
plt.plot(ts, prices)

# %%
fitted_lppl_model = LPPLModel()
fitted_lppl_model.fit(ts, prices)

# %%
plt.plot(ts, fitted_lppl_model(ts))

# %%
print(fitted_lppl_model)
# Out:
# tc: 9.010000000000002
# m: 0.7342124267441169
# omega: 2.5336587100120322
# A: 0.5948400114719079
# B: -0.14118019298668835
# C: 0.013694091899940971
# phi: 0.00051736615602582

# %%
print(lppl_model)
# Out:
# tc: 10.0
# m: 0.445
# omega: 7.877
# A: 1.0
# B: -0.4
# C: 0.025
# phi: 4.1
